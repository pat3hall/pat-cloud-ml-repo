# %%
import numpy as np
import pandas as pd

# %%
# load earthquake dataset
df1 = pd.read_csv("earthquakes-dataset_lesson3_3.csv")
# verify data was loaded
# report number of columns and rows
print(f"df1.shape: {df1.shape}")
# report 1st 3 lines plus column labels
print("\ndf1.head(3):")
df1.head(3)
# Out:
# df1.shape: (23412, 21)
#
# df1.head(3):
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
#
# [3 rows x 21 columns]

# %%
date_demo = "21st of July 2000"
print (f"date_demo: {date_demo}")
date_demo_datetime = pd.to_datetime(date_demo)
print (f"date_demo_datetime: {date_demo_datetime}")
# Out:
# date_demo: 21st of July 2000
# date_demo_datetime: 2000-07-21 00:00:00

# %%
# create Datetime field which merges 'Date' and 'Time' columns 
# Note: add "errors = 'coerce'" argument so that invalid parsing results in empty values instead of failing
df1['Datetime'] =  pd.to_datetime(df1['Date'] + ' ' + df1['Time'], errors = 'coerce')
# verify new Datetime column
df1.head(3)
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# 0                  NaN               NaN               NaN  ISCGEM860706
# 1                  NaN               NaN               NaN  ISCGEM860737
# 2                  NaN               NaN               NaN  ISCGEM860762
#
#    Source Location Source Magnitude Source     Status            Datetime
# 0  ISCGEM          ISCGEM           ISCGEM  Automatic 1965-01-02 13:44:18
# 1  ISCGEM          ISCGEM           ISCGEM  Automatic 1965-01-04 11:29:49
# 2  ISCGEM          ISCGEM           ISCGEM  Automatic 1965-01-05 18:05:58
#
# [3 rows x 22 columns]

# %%
# display Datetime in 1st row
print (f"df1['Datetime'][0]: {df1['Datetime'][0]}")
# display some 1st datetime info: %A (day of the week), %a (short form of day of the week), %B (month)
df1['Datetime'][0].strftime('%A or %a and is %B')
# Out:
# df1['Datetime'][0]: 1965-01-02 13:44:18
# 'Saturday or Sat and is January'

# %%
# set Datetime column as the index field
df1 = df1.set_index(['Datetime'])
# verify index change
df1.head(3)
# Out:
#                            Date      Time  Latitude  Longitude        Type  \
# Datetime
# 1965-01-02 13:44:18  01/02/1965  13:44:18    19.246    145.616  Earthquake
# 1965-01-04 11:29:49  01/04/1965  11:29:49     1.863    127.352  Earthquake
# 1965-01-05 18:05:58  01/05/1965  18:05:58   -20.579   -173.972  Earthquake
#
#                      Depth  Depth Error  Depth Seismic Stations  Magnitude  \
# Datetime
# 1965-01-02 13:44:18  131.6          NaN                     NaN        6.0
# 1965-01-04 11:29:49   80.0          NaN                     NaN        5.8
# 1965-01-05 18:05:58   20.0          NaN                     NaN        6.2
#
#                     Magnitude Type  ...  Magnitude Seismic Stations  \
# Datetime                            ...
# 1965-01-02 13:44:18             MW  ...                         NaN
# 1965-01-04 11:29:49             MW  ...                         NaN
# 1965-01-05 18:05:58             MW  ...                         NaN
#
#                      Azimuthal Gap  Horizontal Distance  Horizontal Error  \
# Datetime
# 1965-01-02 13:44:18            NaN                  NaN               NaN
# 1965-01-04 11:29:49            NaN                  NaN               NaN
# 1965-01-05 18:05:58            NaN                  NaN               NaN
#
#                      Root Mean Square            ID  Source Location Source  \
# Datetime
# 1965-01-02 13:44:18               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1965-01-04 11:29:49               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 1965-01-05 18:05:58               NaN  ISCGEM860762  ISCGEM          ISCGEM
#
#                     Magnitude Source     Status
# Datetime
# 1965-01-02 13:44:18           ISCGEM  Automatic
# 1965-01-04 11:29:49           ISCGEM  Automatic
# 1965-01-05 18:05:58           ISCGEM  Automatic
#
# [3 rows x 21 columns]

# %%
# check the datatypes set when CSV file was read in (sometimes not set correctly)
df1.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
# convert Depth column from floating point to integer (using astype() method)
df1['Depth'] = df1['Depth'].astype(int)
# verify change
df1.head(3)
# Out:
#                            Date      Time  Latitude  Longitude        Type  \
# Datetime
# 1965-01-02 13:44:18  01/02/1965  13:44:18    19.246    145.616  Earthquake
# 1965-01-04 11:29:49  01/04/1965  11:29:49     1.863    127.352  Earthquake
# 1965-01-05 18:05:58  01/05/1965  18:05:58   -20.579   -173.972  Earthquake
#
#                      Depth  Depth Error  Depth Seismic Stations  Magnitude  \
# Datetime
# 1965-01-02 13:44:18    131          NaN                     NaN        6.0
# 1965-01-04 11:29:49     80          NaN                     NaN        5.8
# 1965-01-05 18:05:58     20          NaN                     NaN        6.2
#
#                     Magnitude Type  ...  Magnitude Seismic Stations  \
# Datetime                            ...
# 1965-01-02 13:44:18             MW  ...                         NaN
# 1965-01-04 11:29:49             MW  ...                         NaN
# 1965-01-05 18:05:58             MW  ...                         NaN
#
#                      Azimuthal Gap  Horizontal Distance  Horizontal Error  \
# Datetime
# 1965-01-02 13:44:18            NaN                  NaN               NaN
# 1965-01-04 11:29:49            NaN                  NaN               NaN
# 1965-01-05 18:05:58            NaN                  NaN               NaN
#
#                      Root Mean Square            ID  Source Location Source  \
# Datetime
# 1965-01-02 13:44:18               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1965-01-04 11:29:49               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 1965-01-05 18:05:58               NaN  ISCGEM860762  ISCGEM          ISCGEM
#
#                     Magnitude Source     Status
# Datetime
# 1965-01-02 13:44:18           ISCGEM  Automatic
# 1965-01-04 11:29:49           ISCGEM  Automatic
# 1965-01-05 18:05:58           ISCGEM  Automatic
#
# [3 rows x 21 columns]

# %%
# re-read CSV file, this time, merging 'Date' and 'Time' columns
df1 = pd.read_csv("earthquakes-dataset_lesson3_3.csv", index_col= 0, parse_dates= [['Date', 'Time']])
# verify updated dataframe
df1.head(3)
# Out:
#                      Latitude  Longitude        Type  Depth  Depth Error  \
# Date_Time
# 01/02/1965 13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 01/04/1965 11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 01/05/1965 18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
#
#                      Depth Seismic Stations  Magnitude Magnitude Type  \
# Date_Time
# 01/02/1965 13:44:18                     NaN        6.0             MW
# 01/04/1965 11:29:49                     NaN        5.8             MW
# 01/05/1965 18:05:58                     NaN        6.2             MW
#
#                      Magnitude Error  Magnitude Seismic Stations  \
# Date_Time
# 01/02/1965 13:44:18              NaN                         NaN
# 01/04/1965 11:29:49              NaN                         NaN
# 01/05/1965 18:05:58              NaN                         NaN
#
#                      Azimuthal Gap  Horizontal Distance  Horizontal Error  \
# Date_Time
# 01/02/1965 13:44:18            NaN                  NaN               NaN
# 01/04/1965 11:29:49            NaN                  NaN               NaN
# 01/05/1965 18:05:58            NaN                  NaN               NaN
#
#                      Root Mean Square            ID  Source Location Source  \
# Date_Time
# 01/02/1965 13:44:18               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 01/04/1965 11:29:49               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 01/05/1965 18:05:58               NaN  ISCGEM860762  ISCGEM          ISCGEM
#
#                     Magnitude Source     Status
# Date_Time
# 01/02/1965 13:44:18           ISCGEM  Automatic
# 01/04/1965 11:29:49           ISCGEM  Automatic
# 01/05/1965 18:05:58           ISCGEM  Automatic

# %%
# check index type (object or datetime?)
df1.index
# Out:
# Index(['01/02/1965 13:44:18', '01/04/1965 11:29:49', '01/05/1965 18:05:58',
#        '01/08/1965 18:49:43', '01/09/1965 13:32:50', '01/10/1965 13:36:32',
#        '01/12/1965 13:32:25', '01/15/1965 23:17:42', '01/16/1965 11:32:37',
#        '01/17/1965 10:43:17',
#        ...
#        '12/24/2016 03:58:55', '12/25/2016 14:22:27', '12/25/2016 14:32:13',
#        '12/27/2016 23:20:56', '12/28/2016 08:18:01', '12/28/2016 08:22:12',
#        '12/28/2016 09:13:47', '12/28/2016 12:38:51', '12/29/2016 22:30:19',
#        '12/30/2016 20:08:28'],
#       dtype='object', name='Date_Time', length=23412)

# %%
# df1.index return 'object' type, so convert index to 'datetime' type
df1.index = pd.to_datetime(df1.index, errors='coerce')
# verify df.index converted to 'datetime' type
df1.index
# Out:
# DatetimeIndex(['1965-01-02 13:44:18', '1965-01-04 11:29:49',
#                '1965-01-05 18:05:58', '1965-01-08 18:49:43',
#                '1965-01-09 13:32:50', '1965-01-10 13:36:32',
#                '1965-01-12 13:32:25', '1965-01-15 23:17:42',
#                '1965-01-16 11:32:37', '1965-01-17 10:43:17',
#                ...
#                '2016-12-24 03:58:55', '2016-12-25 14:22:27',
#                '2016-12-25 14:32:13', '2016-12-27 23:20:56',
#                '2016-12-28 08:18:01', '2016-12-28 08:22:12',
#                '2016-12-28 09:13:47', '2016-12-28 12:38:51',
#                '2016-12-29 22:30:19', '2016-12-30 20:08:28'],
#               dtype='datetime64[ns]', name='Date_Time', length=23412, freq=None)

# %%
# used 'info()' to determine columns with null values
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23412 entries, 1965-01-02 13:44:18 to 2016-12-30 20:08:28
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Latitude                    23412 non-null  float64
#  1   Longitude                   23412 non-null  float64
#  2   Type                        23412 non-null  object
#  3   Depth                       23412 non-null  float64
#  4   Depth Error                 4461 non-null   float64
#  5   Depth Seismic Stations      7097 non-null   float64
#  6   Magnitude                   23412 non-null  float64
#  7   Magnitude Type              23409 non-null  object
#  8   Magnitude Error             327 non-null    float64
#  9   Magnitude Seismic Stations  2564 non-null   float64
#  10  Azimuthal Gap               7299 non-null   float64
#  11  Horizontal Distance         1604 non-null   float64
#  12  Horizontal Error            1156 non-null   float64
#  13  Root Mean Square            17352 non-null  float64
#  14  ID                          23412 non-null  object
#  15  Source                      23412 non-null  object
#  16  Location Source             23412 non-null  object
#  17  Magnitude Source            23412 non-null  object
#  18  Status                      23412 non-null  object
# dtypes: float64(12), object(7)
# memory usage: 3.6+ MB

# %%
# drop all the columns (axis=1) with null values in some rows using 'dropna()'
df1 = df1.dropna(axis = 1)
# check 1st 3 rows
df1.head(3)
# Out:
#                      Latitude  Longitude        Type  Depth  Magnitude  \
# Date_Time
# 1965-01-02 13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1965-01-04 11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 1965-01-05 18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
#
#                                ID  Source Location Source Magnitude Source  \
# Date_Time
# 1965-01-02 13:44:18  ISCGEM860706  ISCGEM          ISCGEM           ISCGEM
# 1965-01-04 11:29:49  ISCGEM860737  ISCGEM          ISCGEM           ISCGEM
# 1965-01-05 18:05:58  ISCGEM860762  ISCGEM          ISCGEM           ISCGEM
#
#                         Status
# Date_Time
# 1965-01-02 13:44:18  Automatic
# 1965-01-04 11:29:49  Automatic
# 1965-01-05 18:05:58  Automatic

# %%
# use 'info()' to show remain colunms and if all rows with null values have been removed
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23412 entries, 1965-01-02 13:44:18 to 2016-12-30 20:08:28
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Latitude          23412 non-null  float64
#  1   Longitude         23412 non-null  float64
#  2   Type              23412 non-null  object
#  3   Depth             23412 non-null  float64
#  4   Magnitude         23412 non-null  float64
#  5   ID                23412 non-null  object
#  6   Source            23412 non-null  object
#  7   Location Source   23412 non-null  object
#  8   Magnitude Source  23412 non-null  object
#  9   Status            23412 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 2.0+ MB

# %%
# create a new dataframe, df2, with only the most important columns
df2 = df1[['Latitude', 'Longitude', 'Type', 'Depth', 'Magnitude']]
# check results (3 rows) 'sample()' which randomly picks row
df2.sample(3)
# Out:
#                      Latitude  Longitude        Type  Depth  Magnitude
# Date_Time
# 1989-02-10 12:59:31     2.429    126.700  Earthquake   33.0        5.6
# 2000-01-19 07:09:34    36.372     70.379  Earthquake  206.9        6.0
# 1986-10-14 13:07:19   -43.142     41.776  Earthquake   10.0        6.2

# %%
# use 'unique()' to check the unique values in the 'Type' column
df2.Type.unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
# determine earthquake with largest 'Magnitude' in dataset
df2[df2.Type == "Earthquake"].Magnitude.max()
# Out:
# 9.1

# %%
# determine earthquake with largest 'Depth' (reported in KM) in dataset
df2[df2.Type == "Earthquake"].Depth.max()
# Out:
# 700.0

# %%
# determine earthquake with smallest 'Depth' in dataset
df2[df2.Type == "Earthquake"].Depth.min()
# Out:
# -1.1

# %%
# How many earthquakes in dataset (exmine Type "Earthquake" in results )
df2.Type.value_counts()
# Out:
# Type
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: count, dtype: int64

# %%
# determine average Magnitude of earthquakes in 12 month periods using 'resample()' with mean()
df2['Magnitude'][df2.Type == 'Earthquake'].resample('12M').mean()
# Out:
# Date_Time
# 1965-01-31    6.123077
# 1966-01-31    6.003254
# 1967-01-31    6.042218
# 1968-01-31    6.019835
# 1969-01-31    6.089216
# 1970-01-31    6.001246
# 1971-01-31    6.028329
# 1972-01-31    5.988542
# 1973-01-31    5.920844
# 1974-01-31    5.804455
# 1975-01-31    5.829370
# 1976-01-31    5.844240
# 1977-01-31    5.824279
# 1978-01-31    5.782692
# 1979-01-31    5.821320
# 1980-01-31    5.819308
# 1981-01-31    5.866860
# 1982-01-31    5.863133
# 1983-01-31    5.807872
# 1984-01-31    5.875708
# 1985-01-31    5.852311
# 1986-01-31    5.891922
# 1987-01-31    5.872316
# 1988-01-31    5.894343
# 1989-01-31    5.850533
# 1990-01-31    5.836157
# 1991-01-31    5.870382
# 1992-01-31    5.880988
# 1993-01-31    5.883418
# 1994-01-31    5.891457
# 1995-01-31    5.874904
# 1996-01-31    5.904625
# 1997-01-31    5.874011
# 1998-01-31    5.867364
# 1999-01-31    5.857447
# 2000-01-31    5.886688
# 2001-01-31    5.868525
# 2002-01-31    5.870507
# 2003-01-31    5.867206
# 2004-01-31    5.878360
# 2005-01-31    5.846219
# 2006-01-31    5.871577
# 2007-01-31    5.857414
# 2008-01-31    5.886432
# 2009-01-31    5.909441
# 2010-01-31    5.859429
# 2011-01-31    5.906801
# 2012-01-31    5.863766
# 2013-01-31    5.871167
# 2014-01-31    5.876190
# 2015-01-31    5.884719
# 2016-01-31    5.926201
# 2017-01-31    5.888056
# Name: Magnitude, dtype: float64

# %%
# determine std deviation earthquakes Magnitudes in 12 month periods using 'resample()' with std()
df2['Magnitude'][df2.Type == 'Earthquake'].resample('12M').std()
# Out:
# Date_Time
# 1965-01-31    0.683318
# 1966-01-31    0.454213
# 1967-01-31    0.440944
# 1968-01-31    0.410671
# 1969-01-31    0.479872
# 1970-01-31    0.412309
# 1971-01-31    0.430897
# 1972-01-31    0.464987
# 1973-01-31    0.419704
# 1974-01-31    0.371009
# 1975-01-31    0.385333
# 1976-01-31    0.430614
# 1977-01-31    0.402297
# 1978-01-31    0.379903
# 1979-01-31    0.411788
# 1980-01-31    0.392342
# 1981-01-31    0.404997
# 1982-01-31    0.398501
# 1983-01-31    0.381398
# 1984-01-31    0.438739
# 1985-01-31    0.405411
# 1986-01-31    0.425022
# 1987-01-31    0.393275
# 1988-01-31    0.423271
# 1989-01-31    0.395629
# 1990-01-31    0.376860
# 1991-01-31    0.429076
# 1992-01-31    0.430069
# 1993-01-31    0.409164
# 1994-01-31    0.406829
# 1995-01-31    0.423134
# 1996-01-31    0.445196
# 1997-01-31    0.429527
# 1998-01-31    0.421216
# 1999-01-31    0.416395
# 2000-01-31    0.413840
# 2001-01-31    0.436487
# 2002-01-31    0.415136
# 2003-01-31    0.429939
# 2004-01-31    0.424789
# 2005-01-31    0.401266
# 2006-01-31    0.423383
# 2007-01-31    0.398057
# 2008-01-31    0.432334
# 2009-01-31    0.417207
# 2010-01-31    0.423196
# 2011-01-31    0.457307
# 2012-01-31    0.400249
# 2013-01-31    0.451289
# 2014-01-31    0.449676
# 2015-01-31    0.428857
# 2016-01-31    0.466576
# 2017-01-31    0.442928
# Name: Magnitude, dtype: float64

# %%
# find when the largest (Magnitude = 9.1) earthquake occurred
df2.loc[df2['Magnitude'] == 9.1]
# Out:
#                      Latitude  Longitude        Type  Depth  Magnitude
# Date_Time
# 2004-12-26 00:58:53     3.295     95.982  Earthquake   30.0        9.1
# 2011-03-11 05:46:24    38.297    142.373  Earthquake   29.0        9.1

# %%
# find when the smallest Depth (Depth = -1.1) earthquake occurred
df2.loc[df2['Depth'] == -1.1]
# Out:
#                      Latitude  Longitude        Type  Depth  Magnitude
# Date_Time
# 1992-06-28 12:00:45    34.131   -116.408  Earthquake   -1.1       5.77

# %%
# find out how many nuclear explosions per year since 1965 (in dataset)
df2.index.year[df2.Type == 'Nuclear Explosion'].value_counts().sort_index()
# Out:
# Date_Time
# 1966.0     1
# 1968.0     2
# 1969.0     1
# 1970.0     1
# 1973.0     6
# 1974.0     6
# 1975.0     9
# 1976.0    10
# 1977.0     8
# 1978.0    15
# 1979.0    13
# 1980.0    13
# 1981.0     8
# 1982.0     6
# 1983.0    10
# 1984.0    14
# 1985.0     6
# 1986.0     1
# 1987.0    16
# 1988.0    10
# 1989.0     7
# 1990.0     4
# 1991.0     1
# 1992.0     1
# 1993.0     1
# 1994.0     2
# 1995.0     2
# 1996.0     1
# Name: count, dtype: int64

# %%
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# enable embedding static matplotlib plots in notebook
# %matplotlib inline
# another similiar option is: %matplotlib notebook

# %%
# create a histogram of Magnitude of earthquakes
plt.hist(df2['Magnitude'])
# add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('1969-2016 Earthquakes')
# Out:
# Text(0.5, 1.0, '1969-2016 Earthquakes')

# %%
# create a histogram of Magnitude of earthquakes - specify number bins and add black edgecolor
plt.hist(df2['Magnitude'], bins=10, edgecolor = "black")
# add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('1969-2016 Earthquakes')
# Out:
# Text(0.5, 1.0, '1969-2016 Earthquakes')

# %%
#  update histogram- explicitly specify 11 bins between Magnitudes of 6 and 7
plt.hist(df2['Magnitude'], bins=[6,6.1,6.2,6.3,6.4,6.5,6.6,6.7,6.8,6.9,7], edgecolor = "black")
# add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('1969-2016 Earthquakes')
# Out:
# Text(0.5, 1.0, '1969-2016 Earthquakes')

# %%
# define Earthqaake Magnitude histogram ploting function with number of bins as input
def myplot(bins):
    # create a histogram of Magnitude of earthquakes - pass in the number bins and add black edgecolor
    plt.hist(df2['Magnitude'], bins=bins, edgecolor = "black")
    # add labels and title
    plt.xlabel('Magnitude')
    plt.ylabel('Number of Earthquakes')
    plt.title(f'1969-2016 Earthquakes - bins:{bins}')

# %%
# plot histogram with 20 bins
myplot(20)

# %%
# create a histogram of Magnitude of earthquakes - with 20 bins and between 8 and 9.1
plt.hist(df2['Magnitude'], bins=20, edgecolor = "black", range = [8, 9.1])
# add labels and title
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('1969-2016 Earthquakes - 20 bins between 8 and 9.1')
# Out:
# Text(0.5, 1.0, '1969-2016 Earthquakes - 20 bins between 8 and 9.1')

# %%
# create a earthquake Magnitude line chart showing largest earthquake during each year (using resample for 1 year + max)
plt.plot(df2['Magnitude'][df2.Type == "Earthquake"].resample('1Y').max())

# %%
# check shape of bar expected inputs
df2.index.year.unique().shape
# Out:
# (53,)

# %%
df2.index.year[df2.Type == 'Earthquake'].value_counts().sort_index().shape
# Out:
# (52,)

# %%
# mismatch shape's reported (53,) vs (52,) - may have null values - need to find null values
df2.index.year.isnull().sum()
# Out:
# 3

# %%
# reported 3 null values - need find rows
df2.loc[df2.index.year.isnull()]
# Out:
#            Latitude  Longitude        Type  Depth  Magnitude
# Date_Time
# NaT           8.017    124.075  Earthquake  623.0        5.6
# NaT         -32.998    -71.766  Earthquake   33.0        5.6
# NaT          36.344    142.344  Earthquake   10.1        5.8

# %%
# found 3 rows with null Date_Time index values - need reset index, drop Date_Time null values, then set index to 'Date_Time'
df2 = df2.reset_index().dropna().set_index('Date_Time')

# %%
# create a earthquake Magnitude bar chart showing number of earthquakes per year
plt.bar(df2.index.year.unique(),df2.index.year[df2.Type == 'Earthquake'].value_counts().sort_index())
plt.title('Earthquakes per year')
# Out:
# Text(0.5, 1.0, 'Earthquakes per year')

# %%
# previous bar chart showed earthquakes per year were increasing
# Now, check for nuclear explosions per year
plt.bar(df2[df2.Type == 'Nuclear Explosion'].index.year.unique(), 
        df2.index.year[df2.Type == 'Nuclear Explosion'].value_counts().sort_index())
plt.title('Nuclear Explosions per year')
# Out:
# Text(0.5, 1.0, 'Nuclear Explosions per year')

# %%
# Create a scatter plot for earthquakes per year
plt.scatter(df2[df2.Type == 'Earthquake'].index.year.unique(), 
        df2.index.year[df2.Type == 'Earthquake'].value_counts().sort_index())
plt.title('Earthquakes per year scatter plot')
# Out:
# Text(0.5, 1.0, 'Earthquakes per year scatter plot')

# %%
# Create a bubble chart (scatter plot with depth variable [bubble size]) for earthquakes per year
plt.scatter(df2[df2.Type == 'Earthquake'].index.year.unique(), 
        df2.index.year[df2.Type == 'Earthquake'].value_counts().sort_index(), 
        df2['Depth'][df2.Type == "Earthquake"].resample('1Y').max())
plt.title('Earthquakes max depth per year Bubble Chart')
# Out:
# Text(0.5, 1.0, 'Earthquakes max depth per year Bubble Chart')

# %%
# Create a bubble chart (scatter plot with depth variable [bubble size]) for earthquakes per year
# change bubble color to 'green' and alpha blending factor
plt.scatter(df2[df2.Type == 'Earthquake'].index.year.unique(), 
        df2.index.year[df2.Type == 'Earthquake'].value_counts().sort_index(), 
        df2['Depth'][df2.Type == "Earthquake"].resample('1Y').mean(), 'green', alpha=0.7 )
plt.title('Earthquakes mean depth per year Bubble Chart in green with alpha=0.7')
# Out:
# Text(0.5, 1.0, 'Earthquakes mean depth per year Bubble Chart in green with alpha=0.7')

# %%
# scatter plot for Magnitude vs depth
plt.scatter(df2['Magnitude'], df2['Depth'])
plt.title('Magnitude vs Depth Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Magnitude vs Depth Scatter Plot')

# %%
# map earthquakes by longitude and latitude
# set figure size to width: 19 inches x height: 10 inches (default 6.4 x 4,8)
plt.figure(figsize= (19,10))
# plt.scatter(<x>->Longitude, <y>->Latitude, <size>->Magnitude*10, <color>->Depth)
plt.scatter(df2['Longitude'], df2['Latitude'], df2['Magnitude'] * 10, df2['Depth'])
