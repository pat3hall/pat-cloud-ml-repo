# %%
# !pip install -U sagemaker

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor

region = boto3.session.Session().region_name

#role = get_execution_role()
role ="arn:aws:iam::012345678901:role/service-role/AmazonSageMaker-ExecutionRole-20241024T173132"
sklearn_processor = SKLearnProcessor(
    framework_version="0.20.0", role=role, instance_type="ml.m5.xlarge", instance_count=1
)
# Out:
# C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\pydantic\_internal\_fields.py:172: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [11/19/24 13:21:48] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=525784;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\credentials.py\credentials.py]8;;\:]8;id=974027;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\credentials.py#1278\1278]8;;\
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\pat\AppData\Local\sagemaker\sagemaker\config.yaml
# [11/19/24 13:21:49] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=838392;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\credentials.py\credentials.py]8;;\:]8;id=762883;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\credentials.py#1278\1278]8;;\
# [11/19/24 13:21:50] INFO     Defaulting to only available Python version: py3                     ]8;id=262420;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\image_uris.py\image_uris.py]8;;\:]8;id=16953;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\image_uris.py#603\603]8;;\

# %%
# !pip install --upgrade s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2024.10.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.15.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: fsspec==2024.10.0.* in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from s3fs) (2024.10.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs)
#   Downloading aiohttp-3.11.6-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting botocore<1.35.37,>=1.35.16 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.35.36-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading frozenlist-1.5.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading multidict-6.1.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading propcache-0.2.0-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading yarl-1.17.2-cp311-cp311-win_amd64.whl.metadata (68 kB)
#      ---------------------------------------- 0.0/68.8 kB ? eta -:--:--
#      ----------------------- ---------------- 41.0/68.8 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 68.8/68.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.26.18)
# Requirement already satisfied: idna>=2.0 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\pat\anaconda3\envs\agc-introtojupyternotebooks\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Downloading s3fs-2024.10.0-py3-none-any.whl (29 kB)
# Downloading aiobotocore-2.15.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.4 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/77.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 77.4/77.4 kB 1.4 MB/s eta 0:00:00
# Downloading aiohttp-3.11.6-cp311-cp311-win_amd64.whl (440 kB)
#    ---------------------------------------- 0.0/440.8 kB ? eta -:--:--
#    ------- -------------------------------- 81.9/440.8 kB 2.3 MB/s eta 0:00:01
#    -------------- ------------------------- 163.8/440.8 kB 2.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 194.6/440.8 kB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 256.0/440.8 kB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 307.2/440.8 kB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 409.6/440.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 440.8/440.8 kB 1.5 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading botocore-1.35.36-py3-none-any.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12
2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.19.1 requires filelock, which is not installed.
# datasets 2.19.1 requires pyarrow-hotfix, which is not installed.
# datasets 2.19.1 requires xxhash, which is not installed.
# datasets 2.19.1 requires dill<0.3.9,>=0.3.0, but you have dill 0.3.9 which is incompatible.
# datasets 2.19.1 requires fsspec[http]<=2024.3.1,>=2023.1.0, but you have fsspec 2024.10.0 which is incompatible.
# boto3 1.35.48 requires botocore<1.36.0,>=1.35.48, but you have botocore 1.35.36 which is incompatible.

# %%
import pandas as pd

input_data = "s3://sagemaker-sample-data-{}/processing/census/census-income.csv".format(region)
df = pd.read_csv(input_data, nrows=10)
df.head(n=10)
# Out:
# [11/19/24 13:23:05] INFO     Found credentials in shared credentials file: ~/.aws/credentials    ]8;id=676263;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\aiobotocore\credentials.py\credentials.py]8;;\:]8;id=326912;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\aiobotocore\credentials.py#621\621]8;;\
#    age                  class of worker  detailed industry recode  \
# 0   73                  Not in universe                         0
# 1   58   Self-employed-not incorporated                         4
# 2   18                  Not in universe                         0
# 3    9                  Not in universe                         0
# 4   10                  Not in universe                         0
# 5   48                          Private                        40
# 6   42                          Private                        34
# 7   28                          Private                         4
# 8   47                 Local government                        43
# 9   34                          Private                         4
#
#    detailed occupation recode                    education  wage per hour  \
# 0                           0         High school graduate              0
# 1                          34   Some college but no degree              0
# 2                           0                   10th grade              0
# 3                           0                     Children              0
# 4                           0                     Children              0
# 5                          10   Some college but no degree           1200
# 6                           3   Bachelors degree(BA AB BS)              0
# 7                          40         High school graduate              0
# 8                          26   Some college but no degree            876
# 9                          37   Some college but no degree              0
#
#   enroll in edu inst last wk                      marital stat  \
# 0            Not in universe                           Widowed
# 1            Not in universe                          Divorced
# 2                High school                     Never married
# 3            Not in universe                     Never married
# 4            Not in universe                     Never married
# 5            Not in universe   Married-civilian spouse present
# 6            Not in universe   Married-civilian spouse present
# 7            Not in universe                     Never married
# 8            Not in universe   Married-civilian spouse present
# 9            Not in universe   Married-civilian spouse present
#
#                   major industry code                   major occupation code  \
# 0         Not in universe or children                         Not in universe
# 1                        Construction     Precision production craft & repair
# 2         Not in universe or children                         Not in universe
# 3         Not in universe or children                         Not in universe
# 4         Not in universe or children                         Not in universe
# 5                       Entertainment                  Professional specialty
# 6   Finance insurance and real estate          Executive admin and managerial
# 7                        Construction            Handlers equip cleaners etc
# 8                           Education          Adm support including clerical
# 9                        Construction   Machine operators assmblrs & inspctrs
#
#    ... country of birth father country of birth mother country of birth self  \
# 0  ...           United-States           United-States         United-States
# 1  ...           United-States           United-States         United-States
# 2  ...                 Vietnam                 Vietnam               Vietnam
# 3  ...           United-States           United-States         United-States
# 4  ...           United-States           United-States         United-States
# 5  ...             Philippines           United-States         United-States
# 6  ...           United-States           United-States         United-States
# 7  ...           United-States           United-States         United-States
# 8  ...           United-States           United-States         United-States
# 9  ...           United-States           United-States         United-States
#
#                             citizenship own business or self employed  \
# 0     Native- Born in the United States                             0
# 1     Native- Born in the United States                             0
# 2   Foreign born- Not a citizen of U S                              0
# 3     Native- Born in the United States                             0
# 4     Native- Born in the United States                             0
# 5     Native- Born in the United States                             2
# 6     Native- Born in the United States                             0
# 7     Native- Born in the United States                             0
# 8     Native- Born in the United States                             0
# 9     Native- Born in the United States                             0
#
#   fill inc questionnaire for veteran's admin  veterans benefits  \
# 0                            Not in universe                  2
# 1                            Not in universe                  2
# 2                            Not in universe                  2
# 3                            Not in universe                  0
# 4                            Not in universe                  0
# 5                            Not in universe                  2
# 6                            Not in universe                  2
# 7                            Not in universe                  2
# 8                            Not in universe                  2
# 9                            Not in universe                  2
#
#    weeks worked in year  year     income
# 0                     0    95   - 50000.
# 1                    52    94   - 50000.
# 2                     0    95   - 50000.
# 3                     0    94   - 50000.
# 4                     0    94   - 50000.
# 5                    52    95   - 50000.
# 6                    52    94   - 50000.
# 7                    30    95   - 50000.
# 8                    52    95   - 50000.
# 9                    52    94   - 50000.
#
# [10 rows x 42 columns]

# %%
# %%writefile preprocessing.py

import argparse
import os
import warnings

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelBinarizer, KBinsDiscretizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import make_column_transformer

from sklearn.exceptions import DataConversionWarning

warnings.filterwarnings(action="ignore", category=DataConversionWarning)


columns = [
    "age",
    "education",
    "major industry code",
    "class of worker",
    "num persons worked for employer",
    "capital gains",
    "capital losses",
    "dividends from stocks",
    "income",
]
class_labels = [" - 50000.", " 50000+."]


def print_shape(df):
    negative_examples, positive_examples = np.bincount(df["income"])
    print(
        "Data shape: {}, {} positive examples, {} negative examples".format(
            df.shape, positive_examples, negative_examples
        )
    )


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--train-test-split-ratio", type=float, default=0.3)
    args, _ = parser.parse_known_args()

    print("Received arguments {}".format(args))

    input_data_path = os.path.join("/opt/ml/processing/input", "census-income.csv")

    print("Reading input data from {}".format(input_data_path))
    df = pd.read_csv(input_data_path)
    df = pd.DataFrame(data=df, columns=columns)
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    df.replace(class_labels, [0, 1], inplace=True)

    negative_examples, positive_examples = np.bincount(df["income"])
    print(
        "Data after cleaning: {}, {} positive examples, {} negative examples".format(
            df.shape, positive_examples, negative_examples
        )
    )

    split_ratio = args.train_test_split_ratio
    print("Splitting data into train and test sets with ratio {}".format(split_ratio))
    X_train, X_test, y_train, y_test = train_test_split(
        df.drop("income", axis=1), df["income"], test_size=split_ratio, random_state=0
    )

    preprocess = make_column_transformer(
        (
            ["age", "num persons worked for employer"],
            KBinsDiscretizer(encode="onehot-dense", n_bins=10),
        ),
        (["capital gains", "capital losses", "dividends from stocks"], StandardScaler()),
        (["education", "major industry code", "class of worker"], OneHotEncoder(sparse=False)),
    )
    print("Running preprocessing and feature engineering transformations")
    train_features = preprocess.fit_transform(X_train)
    test_features = preprocess.transform(X_test)

    print("Train data shape after preprocessing: {}".format(train_features.shape))
    print("Test data shape after preprocessing: {}".format(test_features.shape))

    train_features_output_path = os.path.join("/opt/ml/processing/train", "train_features.csv")
    train_labels_output_path = os.path.join("/opt/ml/processing/train", "train_labels.csv")

    test_features_output_path = os.path.join("/opt/ml/processing/test", "test_features.csv")
    test_labels_output_path = os.path.join("/opt/ml/processing/test", "test_labels.csv")

    print("Saving training features to {}".format(train_features_output_path))
    pd.DataFrame(train_features).to_csv(train_features_output_path, header=False, index=False)

    print("Saving test features to {}".format(test_features_output_path))
    pd.DataFrame(test_features).to_csv(test_features_output_path, header=False, index=False)

    print("Saving training labels to {}".format(train_labels_output_path))
    y_train.to_csv(train_labels_output_path, header=False, index=False)

    print("Saving test labels to {}".format(test_labels_output_path))
    y_test.to_csv(test_labels_output_path, header=False, index=False)
# Out:
# Writing preprocessing.py

# %%
from sagemaker.processing import ProcessingInput, ProcessingOutput

sklearn_processor.run(
    code="preprocessing.py",
    inputs=[ProcessingInput(source=input_data, destination="/opt/ml/processing/input")],
    outputs=[
        ProcessingOutput(output_name="train_data", source="/opt/ml/processing/train"),
        ProcessingOutput(output_name="test_data", source="/opt/ml/processing/test"),
    ],
    arguments=["--train-test-split-ratio", "0.2"],
)

preprocessing_job_description = sklearn_processor.jobs[-1].describe()

output_config = preprocessing_job_description["ProcessingOutputConfig"]
for output in output_config["Outputs"]:
    if output["OutputName"] == "train_data":
        preprocessed_training_data = output["S3Output"]["S3Uri"]
    if output["OutputName"] == "test_data":
        preprocessed_test_data = output["S3Output"]["S3Uri"]
# Out:
# [11/19/24 16:14:55] INFO     Creating processing-job with name                                      ]8;id=873775;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py\session.py]8;;\:]8;id=873609;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py#1575\1575]8;;\
#                              sagemaker-scikit-learn-2024-11-20-00-14-54-264
# [11/19/24 16:14:56] ERROR    Please check the troubleshooting guide for common errors:              ]8;id=990823;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py\session.py]8;;\:]8;id=13873;file://C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py#1584\1584]8;;\
#                              https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-t
#                              roubleshooting.html#sagemaker-python-sdk-troubleshooting-create-proces
#                              sing-job
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │    1 from sagemaker.processing import ProcessingInput, ProcessingOutput                          │
# │    2                                                                                             │
# │ ❱  3 sklearn_processor.run(                                                                      │
# │    4 │   code="preprocessing.py",                                                                │
# │    5 │   inputs=[ProcessingInput(source=input_data, destination="/opt/ml/processing/input")],    │
# │    6 │   outputs=[                                                                               │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\workflow\pip │
# │ eline_context.py:346 in wrapper                                                                  │
# │                                                                                                  │
# │   343 │   │   │                                                                                  │
# │   344 │   │   │   return _StepArguments(retrieve_caller_name(self_instance), run_func, *args,    │
# │   345 │   │                                                                                      │
# │ ❱ 346 │   │   return run_func(*args, **kwargs)                                                   │
# │   347 │                                                                                          │
# │   348 │   return wrapper                                                                         │
# │   349                                                                                            │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\processing.p │
# │ y:681 in run                                                                                     │
# │                                                                                                  │
# │    678 │   │   )                                                                                 │
# │    679 │   │                                                                                     │
# │    680 │   │   experiment_config = check_and_get_run_experiment_config(experiment_config)        │
# │ ❱  681 │   │   self.latest_job = ProcessingJob.start_new(                                        │
# │    682 │   │   │   processor=self,                                                               │
# │    683 │   │   │   inputs=normalized_inputs,                                                     │
# │    684 │   │   │   outputs=normalized_outputs,                                                   │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\processing.p │
# │ y:917 in start_new                                                                               │
# │                                                                                                  │
# │    914 │   │   logger.debug("Outputs: %s", process_args["output_config"]["Outputs"])             │
# │    915 │   │                                                                                     │
# │    916 │   │   # Call sagemaker_session.process using the arguments dictionary.                  │
# │ ❱  917 │   │   processor.sagemaker_session.process(**process_args)                               │
# │    918 │   │                                                                                     │
# │    919 │   │   return cls(                                                                       │
# │    920 │   │   │   processor.sagemaker_session,                                                  │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py:1 │
# │ 589 in process                                                                                   │
# │                                                                                                  │
# │   1586 │   │   │   │   )                                                                         │
# │   1587 │   │   │   │   raise e                                                                   │
# │   1588 │   │                                                                                     │
# │ ❱ 1589 │   │   self._intercept_create_request(process_request, submit, self.process.__name__)    │
# │   1590 │                                                                                         │
# │   1591 │   def _get_process_request(                                                             │
# │   1592 │   │   self,                                                                             │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py:6 │
# │ 609 in _intercept_create_request                                                                 │
# │                                                                                                  │
# │   6606 │   │   │   create (functor): a functor calls the sagemaker client create method          │
# │   6607 │   │   │   func_name (str): the name of the function needed intercepting                 │
# │   6608 │   │   """                                                                               │
# │ ❱ 6609 │   │   return create(request)                                                            │
# │   6610 │                                                                                         │
# │   6611 │   def _create_inference_recommendations_job_request(                                    │
# │   6612 │   │   self,                                                                             │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py:1 │
# │ 587 in submit                                                                                    │
# │                                                                                                  │
# │   1584 │   │   │   │   logger.error(                                                             │
# │   1585 │   │   │   │   │   "Please check the troubleshooting guide for common errors: %s", trou  │
# │   1586 │   │   │   │   )                                                                         │
# │ ❱ 1587 │   │   │   │   raise e                                                                   │
# │   1588 │   │                                                                                     │
# │   1589 │   │   self._intercept_create_request(process_request, submit, self.process.__name__)    │
# │   1590                                                                                           │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\sagemaker\session.py:1 │
# │ 577 in submit                                                                                    │
# │                                                                                                  │
# │   1574 │   │   │   try:                                                                          │
# │   1575 │   │   │   │   logger.info("Creating processing-job with name %s", job_name)             │
# │   1576 │   │   │   │   logger.debug("process request: %s", json.dumps(request, indent=4))        │
# │ ❱ 1577 │   │   │   │   self.sagemaker_client.create_processing_job(**request)                    │
# │   1578 │   │   │   except Exception as e:                                                        │
# │   1579 │   │   │   │   troubleshooting = (                                                       │
# │   1580 │   │   │   │   │   "https://docs.aws.amazon.com/sagemaker/latest/dg/"                    │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\client.py:569 │
# │ in _api_call                                                                                     │
# │                                                                                                  │
# │    566 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    567 │   │   │   │   )                                                                         │
# │    568 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  569 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    570 │   │                                                                                     │
# │    571 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    572                                                                                           │
# │                                                                                                  │
# │ C:\Users\pat\anaconda3\envs\agc-introToJupyterNotebooks\Lib\site-packages\botocore\client.py:102 │
# │ 3 in _make_api_call                                                                              │
# │                                                                                                  │
# │   1020 │   │   │   │   "Code"                                                                    │
# │   1021 │   │   │   )                                                                             │
# │   1022 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1023 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1024 │   │   else:                                                                             │
# │   1025 │   │   │   return parsed_response                                                        │
# │   1026                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateProcessingJob operation:
# The account-level service limit 'ml.m5.xlarge for processing job usage' is 0 Instances, with current utilization of
# 0 Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase for this
# quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.

# %%
region
# Out:
# 'us-east-1'
