# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('s3://my-ml-repo-bkt/Parking_Tags_Data_2022.000.csv')
df.head(11)
# Out:
#    tag_number_masked  date_of_infraction  infraction_code  \
# 0           ***73863            20220101               29
# 1           ***46942            20220101               15
# 2           ***73864            20220101               29
# 3           ***63914            20220101                9
# 4           ***73865            20220101               29
# 5           ***63915            20220101                9
# 6           ***46943            20220101                5
# 7           ***63916            20220101                9
# 8           ***46944            20220101                5
# 9           ***63917            20220101                9
# 10          ***65183            20220101              367
#
#             infraction_description  set_fine_amount  time_of_infraction  \
# 0   PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 1   PARK-WITHIN 3M OF FIRE HYDRANT              100                 5.0
# 2   PARK PROHIBITED TIME NO PERMIT               30                 5.0
# 3   STOP-SIGNED HWY-PROHIBIT TM/DY              100                 6.0
# 4   PARK PROHIBITED TIME NO PERMIT               30                 6.0
# 5   STOP-SIGNED HWY-PROHIBIT TM/DY              100                 8.0
# 6   PARK-SIGNED HWY-PROHIBIT DY/TM               50                 9.0
# 7   STOP-SIGNED HWY-PROHIBIT TM/DY              100                 9.0
# 8   PARK-SIGNED HWY-PROHIBIT DY/TM               50                10.0
# 9   STOP-SIGNED HWY-PROHIBIT TM/DY              100                10.0
# 10  STND ONSTRT ACCESSIBLE NO PRMT              450                11.0
#
#    location1             location2 location3 location4 province
# 0        OPP     233 COLERIDGE AVE       NaN       NaN       ON
# 1         NR    25 TOWN CENTRE CRT       NaN       NaN       ON
# 2         NR     252 COLERIDGE AVE       NaN       NaN       MA
# 3         NR     70 DAN LECKIE WAY       NaN       NaN       ON
# 4         NR     262 COLERIDGE AVE       NaN       NaN       ON
# 5         NR     70 DAN LECKIE WAY       NaN       NaN       ON
# 6         NR    55 TOWN CENTRE CRT       NaN       NaN       ON
# 7         NR     70 DAN LECKIE WAY       NaN       NaN       ON
# 8        OPP    55 TOWN CENTRE CRT       NaN       NaN       ON
# 9         NR     70 DAN LECKIE WAY       NaN       NaN       ON
# 10        NR  40 ORCHARD VIEW BLVD       NaN       NaN       ON

# %%
 df.drop(columns='location3')
# Out:
#        tag_number_masked  date_of_infraction  infraction_code  \
# 0               ***73863            20220101               29
# 1               ***46942            20220101               15
# 2               ***73864            20220101               29
# 3               ***63914            20220101                9
# 4               ***73865            20220101               29
# ...                  ...                 ...              ...
# 249994          ***41328            20220308                3
# 249995          ***63242            20220308                4
# 249996          ***63174            20220308                3
# 249997          ***63175            20220308                3
# 249998          ***79558            20220308                5
#
#                 infraction_description  set_fine_amount  time_of_infraction  \
# 0       PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 1       PARK-WITHIN 3M OF FIRE HYDRANT              100                 5.0
# 2       PARK PROHIBITED TIME NO PERMIT               30                 5.0
# 3       STOP-SIGNED HWY-PROHIBIT TM/DY              100                 6.0
# 4       PARK PROHIBITED TIME NO PERMIT               30                 6.0
# ...                                ...              ...                 ...
# 249994        PARK ON PRIVATE PROPERTY               30               823.0
# 249995      PARK ON MUNICIPAL PROPERTY               30               823.0
# 249996        PARK ON PRIVATE PROPERTY               30               823.0
# 249997        PARK ON PRIVATE PROPERTY               30               823.0
# 249998  PARK-SIGNED HWY-PROHIBIT DY/TM               50               823.0
#
#        location1               location2 location4 province
# 0            OPP       233 COLERIDGE AVE       NaN       ON
# 1             NR      25 TOWN CENTRE CRT       NaN       ON
# 2             NR       252 COLERIDGE AVE       NaN       MA
# 3             NR       70 DAN LECKIE WAY       NaN       ON
# 4             NR       262 COLERIDGE AVE       NaN       ON
# ...          ...                     ...       ...      ...
# 249994       NaN    75 THORNCLIFFE PK DR       NaN       ON
# 249995       NaN        1138 BATHURST ST       NaN       ON
# 249996        AT  2183 LAKE SHORE BLVD W       NaN       ON
# 249997        AT  2183 LAKE SHORE BLVD W       NaN       ON
# 249998        NR       107 DEWBOURNE AVE       NaN       ON
#
# [249999 rows x 10 columns]

# %%
df.to_csv('s3://my-ml-repo-bkt/Result.csv')
