# %%
cd "C:/pat-cloud-ml-repo/machine-learning-training/acloudguru-machine-learning-aws-certified-course/demo/5_3_scatterplot_example"
# Out:
# C:\pat-cloud-ml-repo\machine-learning-training\acloudguru-machine-learning-aws-certified-course\demo\5_3_scatterplot_example

# %%
# import python libraries
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in data
df = pd.read_csv ("swedish_insurance.csv")
df.head
# Out:
# <bound method NDFrame.head of       X      Y
# 0   108  392.5
# 1    19   46.2
# 2    13   15.7
# 3   124  422.2
# 4    40  119.4
# ..  ...    ...
# 58    9   87.4
# 59   31  209.8
# 60   14   95.5
# 61   53  244.6
# 62   26  187.5
#
# [63 rows x 2 columns]>

# %%
# plot graph
plt.scatter(x=df['X'], y=df['Y'])
plt.title('Scatter Plot Example')
plt.xlabel('Number of Claims')
plt.ylabel('Total Payed Out (in thousands)')
plt.savefig('Scatter_Plot_Example.png', format='png', dpi=1200)
plt.show()
