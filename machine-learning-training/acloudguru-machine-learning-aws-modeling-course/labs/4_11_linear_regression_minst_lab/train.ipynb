# %% [markdown]
# ![A Cloud Guru](acg_logo.png)
# <hr/>

# %% [markdown]
# <center><h1>Linear Regression Performed Using Amazon SageMaker</h1></center>

# %% [markdown]
# # Introduction
#
# In this lab, you will learn how to import the iris dataset, split it into training and validation data, upload them to S3 bucket, fetch the linear learner algorithm, initialize the estimator object, set the hyperparameters and train the model.

# %% [markdown]
# # How to Use This Lab
#
# Most of the code is provided for you in this lab as our solution to the tasks presented. Some of the cells are left empty with a #TODO header and its your turn to fill in the empty code. You can always use our lab guide if you are stuck.

# %% [markdown]
# # 1) Install dependencies and import the required libraries

# %%
# Install Sagemaker
# !pip install boto3 sagemaker
# Out:
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.35.76)
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (2.237.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.76 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.35.76)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (0.10.3)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (23.2.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: docker in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (7.1.0)
# Requirement already satisfied: fastapi in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (0.115.6)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (6.11.0)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (4.23.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: omegaconf<2.3,>=2.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (1.5.3)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (0.3.3)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (4.3.6)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (4.25.5)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (6.1.0)
# Requirement already satisfied: pyyaml~=6.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (6.0.2)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.17 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (1.0.17)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (3.0.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (4.67.0)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (1.26.19)
# Requirement already satisfied: uvicorn in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker) (0.32.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.76->boto3) (2.9.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from omegaconf<2.3,>=2.2->sagemaker) (4.9.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from packaging>=20.0->sagemaker) (3.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.9.2)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from jsonschema->sagemaker) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from jsonschema->sagemaker) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from jsonschema->sagemaker) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests->sagemaker) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests->sagemaker) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from fastapi->sagemaker) (0.41.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from fastapi->sagemaker) (4.12.2)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pandas->sagemaker) (2024.2)
# Requirement already satisfied: ppft>=1.7.6.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pathos->sagemaker) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pathos->sagemaker) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pathos->sagemaker) (0.70.17)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from uvicorn->sagemaker) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from uvicorn->sagemaker) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.18.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from starlette<0.42.0,>=0.40.0->fastapi->sagemaker) (4.6.2.post1)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi->sagemaker) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi->sagemaker) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (0.1.2)

# %% [markdown]
# 1. We will use the iris dataset as our input data.
# 2. The S3 bucket that you want to use for training data must be within the same region as the Notebook Instance.
# 3. The IAM role is used to provide training and hosting access to your data. See the documentation for how to create these. Note, if more than one role is required for notebook instances, training, and/or hosting, please replace the boto regexp with an appropriate full IAM role arn string(s).

# %%
import sagemaker
import boto3
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Initialize the SageMaker session
sagemaker_session = sagemaker.Session()

# Define the S3 bucket and prefix to store data
output_bucket = sagemaker.Session().default_bucket()
output_prefix = 'sagemaker/linear-learner'
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pydantic/_internal/_fields.py:172: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [12/17/24 02:27:03] INFO     Found credentials from IAM Role:                                   ]8;id=345035;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=678158;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# [12/17/24 02:27:16] INFO     Found credentials from IAM Role:                                   ]8;id=901690;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=10716;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# [12/17/24 02:27:17] INFO     Found credentials from IAM Role:                                   ]8;id=86139;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=479130;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# [12/17/24 02:27:18] INFO     Created S3 bucket: sagemaker-us-east-1-012345678901                     ]8;id=28729;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=998741;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#723\723]8;;\

# %%
#TODO: Fetch the IAM role using the get_execution_role function and assign the value to a variable `role`
role = get_execution_role()
# Out:
# [12/17/24 02:27:36] INFO     Found credentials from IAM Role:                                   ]8;id=501558;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=56929;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# # 2) Download the data and upload them to S3 bucket

# %% [markdown]
# 1. load_iris function is used to download the input data
# 2. The data is split into training and validation data in the ratio of 80 - 20
# 3. The data is saved under 'train.csv' and 'validation.csv'

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Convert to DataFrame for easier manipulation
data = pd.DataFrame(X, columns=iris.feature_names)
data['target'] = y

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#TODO: Use the `train_test_split` function and split the data in a 80 - 20 ratio. 
#TODO: Assign the values to variables `train_data` and `validation_data` 
train_data, validation_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Save to CSV
train_data.to_csv('train.csv', index=False, header=False)
validation_data.to_csv('validation.csv', index=False, header=False)

# %% [markdown]
# Let's use the upload_file function and upload the .csv files to the S3 buckets

# %%
# Upload data to S3
s3 = boto3.client('s3')
s3.upload_file('train.csv', output_bucket, f'{output_prefix}/train/train.csv')
# Out:
# [12/17/24 02:31:05] INFO     Found credentials from IAM Role:                                   ]8;id=295424;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=849629;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %%
#TODO: Using the strategy we followed to upload the training data, as shown above, please upload the validation data to the output bucket.
s3.upload_file('validation.csv', output_bucket, f'{output_prefix}/validation/validation.csv')

# %% [markdown]
# # 3) Set up training and validation data

# %% [markdown]
# Create three separate variables that are dynamically constructed, which will be used as one of the input parameters while generating training inputs.

# %%
# creating the inputs for the fit() function with the training and validation location
s3_train_data = f"s3://{output_bucket}/{output_prefix}/train"
print(f"training files will be taken from: {s3_train_data}")
s3_validation_data = f"s3://{output_bucket}/{output_prefix}/validation"
print(f"validation files will be taken from: {s3_validation_data}")
output_location = f"s3://{output_bucket}/{output_prefix}/output"
print(f"training artifacts output location: {output_location}")
# Out:
# training files will be taken from: s3://sagemaker-us-east-1-012345678901/sagemaker/linear-learner/train
# validation files will be taken from: s3://sagemaker-us-east-1-012345678901/sagemaker/linear-learner/validation
# training artifacts output location: s3://sagemaker-us-east-1-012345678901/sagemaker/linear-learner/output

# %% [markdown]
# Let's create the sagemaker.session.s3_input objects from our data channels. Note that we are using the content_type as text/csv. We use two channels here, one for training and the second for validation.

# %%
# generating the session.s3_input() format for fit() accepted by the sdk
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)

# %%
#TODO: Following the same strategy shown above, please set up a training input for validation data.
#TODO: Name it as `validation_data`
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)

# %% [markdown]
# # 4) Fetch the algorithm and train the model

# %% [markdown]
# Let's retrieve the image for the Linear Learner Algorithm according to the region.

# %%
# Fetch the linear learner image according to the region
from sagemaker.image_uris import retrieve

container = retrieve("linear-learner", boto3.Session().region_name, version="1")
print(container)
deploy_amt_model = True
# Out:
# [12/17/24 02:36:36] INFO     Same images used for training and inference. Defaulting to image     ]8;id=414677;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=298550;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py#387\387]8;;\
#                              scope: inference.
#                     INFO     Ignoring unnecessary instance type: None.                            ]8;id=581370;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=97941;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py#524\524]8;;\
# 382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1

# %% [markdown]
# Then, we create an estimator from the SageMaker Python SDK using the Linear Learner container image and set the training parameters.

# %%
# %%time
import boto3
import sagemaker
from time import gmtime, strftime

sess = sagemaker.Session()

job_name = "linear-learner-iris-regression-" + strftime("%Y%m%d-%H-%M-%S", gmtime())
print("Training job", job_name)

linear = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=output_location,
    sagemaker_session=sagemaker_session,
)
# Out:
# Training job linear-learner-iris-regression-20241217-02-37-17
# CPU times: user 73.5 ms, sys: 7.64 ms, total: 81.1 ms
# Wall time: 95.9 ms

# %% [markdown]
# The hyperparameters are manually configured

# %%
# TODO: Use the set_hyperparameters function and set the following hyperparameters on linear learner
# feature_dim=4, predictor_type='regressor', mini_batch_size=20
linear.set_hyperparameters(
    feature_dim=4,  # Adjust this to match your feature dimension
    predictor_type='regressor',  # Use 'classifier' for classification
    mini_batch_size=20
)

# %% [markdown]
# 1. The following cell will train the algorithm. Training the algorithm involves a few steps. First, the instances that we requested while creating the Estimator classes are provisioned and set up with the appropriate libraries. Then, the data from our channels is downloaded into the instance. Once this is done, the training job begins. The provisioning and data downloading will take time, depending on the size of the data. Therefore, it might be a few minutes before we start getting data logs for our training jobs.
# 2. The log will print the objective metric details.
# 3. The training time takes between 4 and 6 minutes.

# %%
# %%time
linear.fit(inputs={"train": train_data, "validation": validation_data}, job_name=job_name)
# Out:
# [12/17/24 02:39:15] INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=163659;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=641526;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py#90\90]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
#                     INFO     Creating training-job with name:                                       ]8;id=532504;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=447951;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              linear-learner-iris-regression-20241217-02-37-17
# 2024-12-17 02:39:17 Starting - Starting the training job...
# 2024-12-17 02:39:31 Starting - Preparing the instances for training...
# 2024-12-17 02:39:55 Downloading - Downloading input data...
# 2024-12-17 02:40:41 Downloading - Downloading the training image......
# 2024-12-17 02:41:52 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/17/2024 02:41:56 INFO 140300966487872] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/17/2024 02:41:56 INFO 140300966487872] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '4', 'mini_batch_size': '20', 'predictor_type': 'regressor'}
# [12/17/2024 02:41:57 INFO 140300966487872] Final configuration: {'mini_batch_size': '20', 'epochs': '15', 'feature_dim': '4', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [12/17/2024 02:41:59 WARNING 140300966487872] Loggers have already been setup.
# [12/17/2024 02:41:59 INFO 140300966487872] Final configuration: {'mini_batch_size': '20', 'epochs': '15', 'feature_dim': '4', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [12/17/2024 02:41:59 WARNING 140300966487872] Loggers have already been setup.
# Process 8 is a worker.
# [12/17/2024 02:41:59 INFO 140300966487872] Using default worker.
# [12/17/2024 02:41:59 INFO 140300966487872] Checkpoint loading and saving are disabled.
# [12/17/2024 02:41:59 INFO 140300966487872] Create Store: local
# [12/17/2024 02:42:00 INFO 140300966487872] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f99d5940e50>
# [12/17/2024 02:42:00 INFO 140300966487872] Scaling model computed with parameters:
#  {'stdev_label':
# [0.8203653]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [0.4472477  1.7450277  0.74914765 0.81133455]
# <NDArray 4 @cpu(0)>, 'mean_label':
# [5.809167]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.061667  3.726667  1.1833333 0.9916667]
# <NDArray 4 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [12/17/2024 02:42:00 INFO 140300966487872] nvidia-smi: took 0.033 seconds to run.
# [12/17/2024 02:42:00 INFO 140300966487872] nvidia-smi identified 0 GPUs.
# [12/17/2024 02:42:00 INFO 140300966487872] Number of GPUs being used: 0
# #metrics {"StartTime": 1734403320.118558, "EndTime": 1734403320.1186488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 140.0, "count": 1, "min": 140, "max": 140}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 120.0, "count": 1, "min": 120, "max": 120}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1734403320.2387586, "EndTime": 1734403320.23881, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.839529796441396, "count": 1, "min": 0.839529796441396, "max": 0.839529796441396}}}
# #metrics {"StartTime": 1734403320.2388766, "EndTime": 1734403320.2388878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8711329460144043, "count": 1, "min": 0.8711329460144043, "max": 0.8711329460144043}}}
# #metrics {"StartTime": 1734403320.2389274, "EndTime": 1734403320.2389388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.9731606443723043, "count": 1, "min": 0.9731606443723043, "max": 0.9731606443723043}}}
# #metrics {"StartTime": 1734403320.2389722, "EndTime": 1734403320.2389827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.072304900487264, "count": 1, "min": 1.072304900487264, "max": 1.072304900487264}}}
# #metrics {"StartTime": 1734403320.2390256, "EndTime": 1734403320.2390363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7405641794204711, "count": 1, "min": 0.7405641794204711, "max": 0.7405641794204711}}}
# #metrics {"StartTime": 1734403320.2390728, "EndTime": 1734403320.2390842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.7509320934613546, "count": 1, "min": 0.7509320934613546, "max": 0.7509320934613546}}}
# #metrics {"StartTime": 1734403320.2391229, "EndTime": 1734403320.2391334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7756560524304708, "count": 1, "min": 0.7756560524304708, "max": 0.7756560524304708}}}
# #metrics {"StartTime": 1734403320.2391682, "EndTime": 1734403320.2391798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.7749907414118449, "count": 1, "min": 0.7749907414118449, "max": 0.7749907414118449}}}
# #metrics {"StartTime": 1734403320.2392066, "EndTime": 1734403320.2392147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 1.0514742056528728, "count": 1, "min": 1.0514742056528728, "max": 1.0514742056528728}}}
# #metrics {"StartTime": 1734403320.239242, "EndTime": 1734403320.23925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.0439642031987508, "count": 1, "min": 1.0439642031987508, "max": 1.0439642031987508}}}
# #metrics {"StartTime": 1734403320.2392757, "EndTime": 1734403320.239283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8173604726791381, "count": 1, "min": 0.8173604726791381, "max": 0.8173604726791381}}}
# #metrics {"StartTime": 1734403320.2393095, "EndTime": 1734403320.2393172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.9330007513364156, "count": 1, "min": 0.9330007513364156, "max": 0.9330007513364156}}}
# #metrics {"StartTime": 1734403320.2393634, "EndTime": 1734403320.2393732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.7780120611190796, "count": 1, "min": 0.7780120611190796, "max": 0.7780120611190796}}}
# #metrics {"StartTime": 1734403320.2394123, "EndTime": 1734403320.2394228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.7904391407966613, "count": 1, "min": 0.7904391407966613, "max": 0.7904391407966613}}}
# #metrics {"StartTime": 1734403320.239462, "EndTime": 1734403320.2394722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.4782347043355306, "count": 1, "min": 0.4782347043355306, "max": 0.4782347043355306}}}
# #metrics {"StartTime": 1734403320.288153, "EndTime": 1734403320.2881625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.1236665407816569, "count": 1, "min": 0.1236665407816569, "max": 0.1236665407816569}}}
# #metrics {"StartTime": 1734403320.288202, "EndTime": 1734403320.2882128, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.12572207053502402, "count": 1, "min": 0.12572207053502402, "max": 0.12572207053502402}}}
# #metrics {"StartTime": 1734403320.288252, "EndTime": 1734403320.2882624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.7999745051066081, "count": 1, "min": 0.7999745051066081, "max": 0.7999745051066081}}}
# #metrics {"StartTime": 1734403320.288298, "EndTime": 1734403320.2883081, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 0.7738430023193359, "count": 1, "min": 0.7738430023193359, "max": 0.7738430023193359}}}
# #metrics {"StartTime": 1734403320.2883413, "EndTime": 1734403320.28835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 0.7641542434692383, "count": 1, "min": 0.7641542434692383, "max": 0.7641542434692383}}}
# #metrics {"StartTime": 1734403320.288384, "EndTime": 1734403320.2883923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 0.7236588478088379, "count": 1, "min": 0.7236588478088379, "max": 0.7236588478088379}}}
# #metrics {"StartTime": 1734403320.2884254, "EndTime": 1734403320.2884355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 0.6338080406188965, "count": 1, "min": 0.6338080406188965, "max": 0.6338080406188965}}}
# #metrics {"StartTime": 1734403320.2884693, "EndTime": 1734403320.2884803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 0.7683707237243652, "count": 1, "min": 0.7683707237243652, "max": 0.7683707237243652}}}
# #metrics {"StartTime": 1734403320.288513, "EndTime": 1734403320.2885227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.7341007550557455, "count": 1, "min": 0.7341007550557455, "max": 0.7341007550557455}}}
# #metrics {"StartTime": 1734403320.288563, "EndTime": 1734403320.2885737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.6847041130065918, "count": 1, "min": 0.6847041130065918, "max": 0.6847041130065918}}}
# [12/17/2024 02:42:00 INFO 140300966487872] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=0.5610675493876139
# [12/17/2024 02:42:00 INFO 140300966487872] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.1236665407816569
# [12/17/2024 02:42:00 INFO 140300966487872] Epoch 0: Loss improved. Updating best model
# [12/17/2024 02:42:00 INFO 140300966487872] Saving model for epoch: 0
# [12/17/2024 02:42:00 INFO 140300966487872] Saved checkpoint to "/tmp/tmpzio70407/mx-mod-0000.params"
# [12/17/2024 02:42:00 INFO 140300966487872] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1734403320.1192603, "EndTime": 1734403320.2969604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 260.0, "count": 1, "min": 260, "max": 260}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 120.0, "count": 1, "min": 120, "max": 120}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 120.0, "count": 1, "min": 120, "max": 120}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
# [12/17/2024 02:42:00 INFO 140300966487872] #throughput_metric: host=algo-1, train throughput=674.7729000341867 records/second
# #metrics {"StartTime": 1734403320.4164524, "EndTime": 1734403320.4165044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7072443683942159, "count": 1, "min": 0.7072443683942159, "max": 0.7072443683942159}}}
# #metrics {"StartTime": 1734403320.4165733, "EndTime": 1734403320.4165843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7354329466819763, "count": 1, "min": 0.7354329466819763, "max": 0.7354329466819763}}}
# #metrics {"StartTime": 1734403320.416623, "EndTime": 1734403320.4166315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8162133892377218, "count": 1, "min": 0.8162133892377218, "max": 0.8162133892377218}}}
# #metrics {"StartTime": 1734403320.4166615, "EndTime": 1734403320.416672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.9058209419250488, "count": 1, "min": 0.9058209419250488, "max": 0.9058209419250488}}}
# #metrics {"StartTime": 1734403320.4167006, "EndTime": 1734403320.416709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.30211786429087323, "count": 1, "min": 0.30211786429087323, "max": 0.30211786429087323}}}
# #metrics {"StartTime": 1734403320.4167364, "EndTime": 1734403320.4167435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.29561602671941123, "count": 1, "min": 0.29561602671941123, "max": 0.29561602671941123}}}
# #metrics {"StartTime": 1734403320.416771, "EndTime": 1734403320.4167783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.31365816791852313, "count": 1, "min": 0.31365816791852313, "max": 0.31365816791852313}}}
# #metrics {"StartTime": 1734403320.4168057, "EndTime": 1734403320.4168127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.30874400536219276, "count": 1, "min": 0.30874400536219276, "max": 0.30874400536219276}}}
# #metrics {"StartTime": 1734403320.4168394, "EndTime": 1734403320.4168468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8957491437594096, "count": 1, "min": 0.8957491437594096, "max": 0.8957491437594096}}}
# #metrics {"StartTime": 1734403320.4168727, "EndTime": 1734403320.4168801, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.8791937311490376, "count": 1, "min": 0.8791937311490376, "max": 0.8791937311490376}}}
# #metrics {"StartTime": 1734403320.416908, "EndTime": 1734403320.4169154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6867582440376282, "count": 1, "min": 0.6867582440376282, "max": 0.6867582440376282}}}
# #metrics {"StartTime": 1734403320.4169447, "EndTime": 1734403320.416954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7874956488609314, "count": 1, "min": 0.7874956488609314, "max": 0.7874956488609314}}}
# #metrics {"StartTime": 1734403320.4169912, "EndTime": 1734403320.4170003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.3131910264492035, "count": 1, "min": 0.3131910264492035, "max": 0.3131910264492035}}}
# #metrics {"StartTime": 1734403320.4170325, "EndTime": 1734403320.417041, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.33375077644983925, "count": 1, "min": 0.33375077644983925, "max": 0.33375077644983925}}}
# #metrics {"StartTime": 1734403320.4170756, "EndTime": 1734403320.4170856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.2975618541240692, "count": 1, "min": 0.2975618541240692, "max": 0.2975618541240692}}}
# #metrics {"StartTime": 1734403320.4171178, "EndTime": 1734403320.417127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.3005446990331014, "count": 1, "min": 0.3005446990331014, "max": 0.3005446990331014}}}
# #metrics {"StartTime": 1734403320.417159, "EndTime": 1734403320.4171681, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9051866809527079, "count": 1, "min": 0.9051866809527079, "max": 0.9051866809527079}}}
# #metrics {"StartTime": 1734403320.4172034, "EndTime": 1734403320.4172122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7157073299090068, "count": 1, "min": 0.7157073299090068, "max": 0.7157073299090068}}}
# #metrics {"StartTime": 1734403320.4172459, "EndTime": 1734403320.4172564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.76409010887146, "count": 1, "min": 0.76409010887146, "max": 0.76409010887146}}}
# #metrics {"StartTime": 1734403320.417292, "EndTime": 1734403320.4173014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7259528954823812, "count": 1, "min": 0.7259528954823812, "max": 0.7259528954823812}}}
# #metrics {"StartTime": 1734403320.4173357, "EndTime": 1734403320.4173477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.5646904309590658, "count": 1, "min": 0.5646904309590658, "max": 0.5646904309590658}}}
# #metrics {"StartTime": 1734403320.417383, "EndTime": 1734403320.4173932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.5567814350128174, "count": 1, "min": 0.5567814350128174, "max": 0.5567814350128174}}}
# #metrics {"StartTime": 1734403320.4174273, "EndTime": 1734403320.417437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.3398434539635976, "count": 1, "min": 0.3398434539635976, "max": 0.3398434539635976}}}
# #metrics {"StartTime": 1734403320.4174728, "EndTime": 1734403320.4174826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.37314434051513673, "count": 1, "min": 0.37314434051513673, "max": 0.37314434051513673}}}
# #metrics {"StartTime": 1734403320.417532, "EndTime": 1734403320.4175434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.5003849983215332, "count": 1, "min": 0.5003849983215332, "max": 0.5003849983215332}}}
# #metrics {"StartTime": 1734403320.471923, "EndTime": 1734403320.4719322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.13932361205418906, "count": 1, "min": 0.13932361205418906, "max": 0.13932361205418906}}}
# #metrics {"StartTime": 1734403320.4719684, "EndTime": 1734403320.471977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.14069324334462482, "count": 1, "min": 0.14069324334462482, "max": 0.14069324334462482}}}
# #metrics {"StartTime": 1734403320.4720082, "EndTime": 1734403320.472018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.13868891596794128, "count": 1, "min": 0.13868891596794128, "max": 0.13868891596794128}}}
# #metrics {"StartTime": 1734403320.4720504, "EndTime": 1734403320.4720597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.14375436305999756, "count": 1, "min": 0.14375436305999756, "max": 0.14375436305999756}}}
# #metrics {"StartTime": 1734403320.4720926, "EndTime": 1734403320.4721024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.5903749148050944, "count": 1, "min": 0.5903749148050944, "max": 0.5903749148050944}}}
# #metrics {"StartTime": 1734403320.4721382, "EndTime": 1734403320.4721475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.4480666955312093, "count": 1, "min": 0.4480666955312093, "max": 0.4480666955312093}}}
# #metrics {"StartTime": 1734403320.472182, "EndTime": 1734403320.4721918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.4805208524068197, "count": 1, "min": 0.4805208524068197, "max": 0.4805208524068197}}}
# #metrics {"StartTime": 1734403320.4722254, "EndTime": 1734403320.4722357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.454478391011556, "count": 1, "min": 0.454478391011556, "max": 0.454478391011556}}}
# ...
# #metrics {"StartTime": 1734403323.293966, "EndTime": 1734403323.2939794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0102296113967895, "count": 1, "min": 1.0102296113967895, "max": 1.0102296113967895}}}
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, epoch=12, train mse_objective <loss>=0.2773773789405823
# #metrics {"StartTime": 1734403323.3570256, "EndTime": 1734403323.3571227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.13986566464106243, "count": 1, "min": 0.13986566464106243, "max": 0.13986566464106243}}}
# #metrics {"StartTime": 1734403323.3572257, "EndTime": 1734403323.3572707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.13954657316207886, "count": 1, "min": 0.13954657316207886, "max": 0.13954657316207886}}}
# #metrics {"StartTime": 1734403323.357383, "EndTime": 1734403323.3573968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.1470790147781372, "count": 1, "min": 0.1470790147781372, "max": 0.1470790147781372}}}
# #metrics {"StartTime": 1734403323.3574648, "EndTime": 1734403323.3574762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.15925289789835612, "count": 1, "min": 0.15925289789835612, "max": 0.15925289789835612}}}
# #metrics {"StartTime": 1734403323.3577387, "EndTime": 1734403323.3578107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.09829463561375935, "count": 1, "min": 0.09829463561375935, "max": 0.09829463561375935}}}
# #metrics {"StartTime": 1734403323.3579197, "EndTime": 1734403323.358079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.09358333746592204, "count": 1, "min": 0.09358333746592204, "max": 0.09358333746592204}}}
# #metrics {"StartTime": 1734403323.3581712, "EndTime": 1734403323.358186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.09955868224302927, "count": 1, "min": 0.09955868224302927, "max": 0.09955868224302927}}}
# #metrics {"StartTime": 1734403323.358225, "EndTime": 1734403323.3582344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.0967377116282781, "count": 1, "min": 0.0967377116282781, "max": 0.0967377116282781}}}
# #metrics {"StartTime": 1734403323.3582687, "EndTime": 1734403323.358277, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.16008042494455973, "count": 1, "min": 0.16008042494455973, "max": 0.16008042494455973}}}
# #metrics {"StartTime": 1734403323.3583088, "EndTime": 1734403323.3583174, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.15537930329640706, "count": 1, "min": 0.15537930329640706, "max": 0.15537930329640706}}}
# #metrics {"StartTime": 1734403323.3583493, "EndTime": 1734403323.3583577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.13669567902882893, "count": 1, "min": 0.13669567902882893, "max": 0.13669567902882893}}}
# #metrics {"StartTime": 1734403323.3583899, "EndTime": 1734403323.3583977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.14210982322692872, "count": 1, "min": 0.14210982322692872, "max": 0.14210982322692872}}}
# #metrics {"StartTime": 1734403323.3584287, "EndTime": 1734403323.358437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.09923662940661113, "count": 1, "min": 0.09923662940661113, "max": 0.09923662940661113}}}
# #metrics {"StartTime": 1734403323.3584678, "EndTime": 1734403323.3584764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.098398756980896, "count": 1, "min": 0.098398756980896, "max": 0.098398756980896}}}
# #metrics {"StartTime": 1734403323.3585086, "EndTime": 1734403323.3585172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.09581015706062317, "count": 1, "min": 0.09581015706062317, "max": 0.09581015706062317}}}
# #metrics {"StartTime": 1734403323.3585489, "EndTime": 1734403323.358558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.09360167682170868, "count": 1, "min": 0.09360167682170868, "max": 0.09360167682170868}}}
# #metrics {"StartTime": 1734403323.3585901, "EndTime": 1734403323.3585987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.2012921651204427, "count": 1, "min": 0.2012921651204427, "max": 0.2012921651204427}}}
# #metrics {"StartTime": 1734403323.3586607, "EndTime": 1734403323.3586702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.18817080656687418, "count": 1, "min": 0.18817080656687418, "max": 0.18817080656687418}}}
# #metrics {"StartTime": 1734403323.3587072, "EndTime": 1734403323.358716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.19468310674031575, "count": 1, "min": 0.19468310674031575, "max": 0.19468310674031575}}}
# #metrics {"StartTime": 1734403323.3587458, "EndTime": 1734403323.3587527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.1890229304631551, "count": 1, "min": 0.1890229304631551, "max": 0.1890229304631551}}}
# #metrics {"StartTime": 1734403323.3588228, "EndTime": 1734403323.358835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.1917330026626587, "count": 1, "min": 0.1917330026626587, "max": 0.1917330026626587}}}
# #metrics {"StartTime": 1734403323.3589115, "EndTime": 1734403323.3589237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.19567097822825114, "count": 1, "min": 0.19567097822825114, "max": 0.19567097822825114}}}
# #metrics {"StartTime": 1734403323.3590012, "EndTime": 1734403323.3590136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.19701627095540364, "count": 1, "min": 0.19701627095540364, "max": 0.19701627095540364}}}
# #metrics {"StartTime": 1734403323.3591042, "EndTime": 1734403323.3591554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.20484378337860107, "count": 1, "min": 0.20484378337860107, "max": 0.20484378337860107}}}
# #metrics {"StartTime": 1734403323.3592372, "EndTime": 1734403323.3592515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.6905570030212402, "count": 1, "min": 0.6905570030212402, "max": 0.6905570030212402}}}
# #metrics {"StartTime": 1734403323.3593276, "EndTime": 1734403323.3593512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 0.690438715616862, "count": 1, "min": 0.690438715616862, "max": 0.690438715616862}}}
# #metrics {"StartTime": 1734403323.3594291, "EndTime": 1734403323.3594522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 0.6898114840189616, "count": 1, "min": 0.6898114840189616, "max": 0.6898114840189616}}}
# #metrics {"StartTime": 1734403323.3595312, "EndTime": 1734403323.3595743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 0.6888399759928385, "count": 1, "min": 0.6888399759928385, "max": 0.6888399759928385}}}
# #metrics {"StartTime": 1734403323.3596623, "EndTime": 1734403323.359678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 0.6912901878356934, "count": 1, "min": 0.6912901878356934, "max": 0.6912901878356934}}}
# #metrics {"StartTime": 1734403323.3597665, "EndTime": 1734403323.3597906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 0.6947144190470378, "count": 1, "min": 0.6947144190470378, "max": 0.6947144190470378}}}
# #metrics {"StartTime": 1734403323.3598695, "EndTime": 1734403323.359883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.6901092847188314, "count": 1, "min": 0.6901092847188314, "max": 0.6901092847188314}}}
# #metrics {"StartTime": 1734403323.359966, "EndTime": 1734403323.3600144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.6942677815755208, "count": 1, "min": 0.6942677815755208, "max": 0.6942677815755208}}}
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, epoch=12, validation mse_objective <loss>=0.13986566464106243
# [12/17/2024 02:42:03 INFO 140300966487872] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=mse_objective, value=0.09358333746592204
# [12/17/2024 02:42:03 INFO 140300966487872] Saving model for epoch: 12
# [12/17/2024 02:42:03 INFO 140300966487872] Saved checkpoint to "/tmp/tmphie9u19s/mx-mod-0000.params"
# [12/17/2024 02:42:03 INFO 140300966487872] Early stop condition met. Stopping training.
# [12/17/2024 02:42:03 INFO 140300966487872] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1734403323.1353037, "EndTime": 1734403323.3684947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1700.0, "count": 1, "min": 1700, "max": 1700}, "Total Batches Seen": {"sum": 85.0, "count": 1, "min": 85, "max": 85}, "Max Records Seen Between Resets": {"sum": 120.0, "count": 1, "min": 120, "max": 120}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 120.0, "count": 1, "min": 120, "max": 120}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
# [12/17/2024 02:42:03 INFO 140300966487872] #throughput_metric: host=algo-1, train throughput=513.9159974473516 records/second
# [12/17/2024 02:42:03 WARNING 140300966487872] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/17/2024 02:42:03 WARNING 140300966487872] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/17/2024 02:42:03 INFO 140300966487872] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=mse_objective, value=0.09358333746592204
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('mse_objective', 0.08518839677174886)
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('mse', 0.08518839677174886)
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('absolute_loss', 0.22597212791442872)
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('rmse', 0.29187051370727546)
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('r2', 0.876586249827093)
# [12/17/2024 02:42:03 INFO 140300966487872] #validation_score (algo-1) : ('mae', 0.22597212791442872)
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation mse_objective <loss>=0.08518839677174886
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation mse <loss>=0.08518839677174886
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.22597212791442872
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation rmse <loss>=0.29187051370727546
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation r2 <loss>=0.876586249827093
# [12/17/2024 02:42:03 INFO 140300966487872] #quality_metric: host=algo-1, validation mae <loss>=0.22597212791442872
# [12/17/2024 02:42:03 INFO 140300966487872] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [12/17/2024 02:42:03 INFO 140300966487872] Saved checkpoint to "/tmp/tmpy9kxy97n/mx-mod-0000.params"
# [12/17/2024 02:42:03 INFO 140300966487872] Test data is not provided.
# #metrics {"StartTime": 1734403319.9585083, "EndTime": 1734403323.4761732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 159.67655181884766, "count": 1, "min": 159.67655181884766, "max": 159.67655181884766}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 10.465621948242188, "count": 14, "min": 0.21457672119140625, "max": 2.3717880249023438}, "update.time": {"sum": 3191.7483806610107, "count": 13, "min": 165.51566123962402, "max": 446.03896141052246}, "finalize.time": {"sum": 98.50597381591797, "count": 1, "min": 98.50597381591797, "max": 98.50597381591797}, "setuptime": {"sum": 2.093791961669922, "count": 1, "min": 2.093791961669922, "max": 2.093791961669922}, "totaltime": {"sum": 3626.6369819641113, "count": 1, "min": 3626.6369819641113, "max": 3626.6369819641113}}}
#
# 2024-12-17 02:42:07 Uploading - Uploading generated training model
# 2024-12-17 02:42:26 Completed - Training job completed
# Training seconds: 150
# Billable seconds: 150
# CPU times: user 562 ms, sys: 37.8 ms, total: 600 ms
# Wall time: 3min 48s
